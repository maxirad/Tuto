# %% [markdown]
# # How to Markdown
#
# # Title 1
#
# ## Title 2
#
# ### Title 3
#
# #### Title 4
#
# ##### Title 5
#
# To break lines you have to type $<br>$
#
# A double line break will end on a line jump
#
# You can write in  __bold__ by adding __
#
# You can write in  *italic* by adding *
#
# ***
# *** adds a horizontal line
# <br>
#
# ## Mathematics
#
# If you want to write $MATHS$ be sure to surround them with a dollar sign
# <br>
# If doubled  the equation is centered
# $$ f_n(P,S,\boldsymbol\sigma)=\frac{\sqrt{\prod\limits_{i=1}^N {\hat\sigma_i^n}}}{\sum{ \dot {P_i} * \| \tilde {S^n}\|_2}} $$
#
# For a nice function
#
#
# \begin{array}{ccccc}
# f & : & \mathscr{M}_n & \to & \mathbb{R}_+ \\
#  & & \bar A & \mapsto & (x_{t})_{t \in [0:+\infty]} \\
# \end{array}
#
#
#
# ## Indentations
#
#     Code
#     for a nice look:
#         it respects indentation
#     return to work
#
# > Indent
# >> And then you can re indent
# >>> And so on
#
# - Main bullet point
#     - Sub bullet point
#         - Sub sub bullet point
#             - Sub sub sub bullet point
#
#
#  1. You can also
#      1. use numbered
#          1. lists
#              1. yaaas !
#                  1. girl
#
#
# ## Boxes
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly, and only for some specific
# purpose that the other boxes can't cover. For example, if you have a lot
# of related content to link to, maybe you decide to use green boxes for
# related links from each section of a notebook.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes. These should only be
# used for actions that might cause data loss or another major issue.
# </div>
#
# ## Internal/External Links
#
# [Get back to Title 1](#Title-1)
#
# [Go to my Github](https://github.com/maxirad)
